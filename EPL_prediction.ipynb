# %%
import pandas as pd

# %%
matches = pd.read_csv("combined_file.csv", index_col = 0)

# %%
matches.head()
# Out:
#                date   time            comp        round  day venue result  \
# MatchID
# 0        2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W
# 1        2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W
# 2        2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W
# 3        2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L
# 4        2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W
#
#           gf   ga         opponent  ...  match report  notes    sh   sot  \
# MatchID                             ...
# 0        2.0  0.0     Ipswich Town  ...  Match Report    NaN  18.0   5.0
# 1        2.0  0.0        Brentford  ...  Match Report    NaN  19.0   8.0
# 2        3.0  0.0   Manchester Utd  ...  Match Report    NaN  11.0   3.0
# 3        0.0  1.0  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0
# 4        3.0  0.0      Bournemouth  ...  Match Report    NaN  19.0  12.0
#
#          dist   fk pk pkatt season       team
# MatchID
# 0        14.8  0.0  0     0   2024  Liverpool
# 1        13.6  1.0  0     0   2024  Liverpool
# 2        13.4  0.0  0     0   2024  Liverpool
# 3        14.9  0.0  0     0   2024  Liverpool
# 4        16.6  0.0  0     0   2024  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (5778, 28)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester United           289
# Arsenal                     289
# Manchester City             289
# Newcastle United            289
# Chelsea                     289
# Tottenham Hotspur           289
# West Ham United             289
# Brighton and Hove Albion    289
# Crystal Palace              289
# Liverpool                   288
# Everton                     288
# Southampton                 251
# Leicester City              251
# Wolverhampton Wanderers     251
# Burnley                     228
# Aston Villa                 213
# Bournemouth                 213
# Fulham                      175
# Watford                     152
# Brentford                   137
# Sheffield United            114
# Leeds United                114
# Nottingham Forest            99
# Norwich City                 76
# West Bromwich Albion         76
# Huddersfield Town            76
# Luton Town                   38
# Cardiff City                 38
# Swansea City                 38
# Stoke City                   38
# Ipswich Town                 23
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     160
# Matchweek 13    160
# Matchweek 23    160
# Matchweek 22    160
# Matchweek 2     160
# Matchweek 20    160
# Matchweek 19    160
# Matchweek 18    160
# Matchweek 17    160
# Matchweek 16    160
# Matchweek 14    160
# Matchweek 21    160
# Matchweek 12    160
# Matchweek 6     160
# Matchweek 11    160
# Matchweek 4     160
# Matchweek 5     160
# Matchweek 3     160
# Matchweek 7     160
# Matchweek 8     160
# Matchweek 9     160
# Matchweek 10    160
# Matchweek 15    158
# Matchweek 32    140
# Matchweek 34    140
# Matchweek 37    140
# Matchweek 36    140
# Matchweek 35    140
# Matchweek 29    140
# Matchweek 33    140
# Matchweek 26    140
# Matchweek 31    140
# Matchweek 30    140
# Matchweek 28    140
# Matchweek 27    140
# Matchweek 25    140
# Matchweek 24    140
# Matchweek 38    140
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches
# Out:
#               date   time            comp         round  day venue result  \
# MatchID
# 0       2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W
# 1       2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W
# 2       2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W
# 3       2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L
# 4       2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W
# ...            ...    ...             ...           ...  ...   ...    ...
# 5773    2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W
# 5774    2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D
# 5775    2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W
# 5776    2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W
# 5777    2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L
#
#           gf   ga         opponent  ...  match report  notes    sh   sot  \
# MatchID                             ...
# 0        2.0  0.0     Ipswich Town  ...  Match Report    NaN  18.0   5.0
# 1        2.0  0.0        Brentford  ...  Match Report    NaN  19.0   8.0
# 2        3.0  0.0   Manchester Utd  ...  Match Report    NaN  11.0   3.0
# 3        0.0  1.0  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0
# 4        3.0  0.0      Bournemouth  ...  Match Report    NaN  19.0  12.0
# ...      ...  ...              ...  ...           ...    ...   ...   ...
# 5773     1.0  0.0   Manchester Utd  ...  Match Report    NaN  10.0   4.0
# 5774     2.0  2.0        Liverpool  ...  Match Report    NaN  13.0   6.0
# 5775     1.0  0.0    Newcastle Utd  ...  Match Report    NaN   9.0   2.0
# 5776     1.0  0.0        Tottenham  ...  Match Report    NaN   9.0   1.0
# 5777     0.0  2.0   Crystal Palace  ...  Match Report    NaN   7.0   1.0
#
#          dist   fk pk pkatt season                  team
# MatchID
# 0        14.8  0.0  0     0   2024             Liverpool
# 1        13.6  1.0  0     0   2024             Liverpool
# 2        13.4  0.0  0     0   2024             Liverpool
# 3        14.9  0.0  0     0   2024             Liverpool
# 4        16.6  0.0  0     0   2024             Liverpool
# ...       ...  ... ..   ...    ...                   ...
# 5773     18.1  0.0  0     0   2017  West Bromwich Albion
# 5774     17.7  0.0  0     0   2017  West Bromwich Albion
# 5775     20.1  0.0  0     0   2017  West Bromwich Albion
# 5776     10.2  0.0  0     0   2017  West Bromwich Albion
# 5777     24.8  1.0  0     0   2017  West Bromwich Albion
#
# [5778 rows x 28 columns]

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"]= matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex = True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#               date   time            comp         round  day venue result  \
# MatchID
# 0       2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W
# 1       2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W
# 2       2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W
# 3       2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L
# 4       2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W
# ...            ...    ...             ...           ...  ...   ...    ...
# 5773    2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W
# 5774    2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D
# 5775    2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W
# 5776    2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W
# 5777    2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L
#
#           gf   ga         opponent  ...   fk  pk  pkatt  season  \
# MatchID                             ...
# 0        2.0  0.0     Ipswich Town  ...  0.0   0      0    2024
# 1        2.0  0.0        Brentford  ...  1.0   0      0    2024
# 2        3.0  0.0   Manchester Utd  ...  0.0   0      0    2024
# 3        0.0  1.0  Nott'ham Forest  ...  0.0   0      0    2024
# 4        3.0  0.0      Bournemouth  ...  0.0   0      0    2024
# ...      ...  ...              ...  ...  ...  ..    ...     ...
# 5773     1.0  0.0   Manchester Utd  ...  0.0   0      0    2017
# 5774     2.0  2.0        Liverpool  ...  0.0   0      0    2017
# 5775     1.0  0.0    Newcastle Utd  ...  0.0   0      0    2017
# 5776     1.0  0.0        Tottenham  ...  0.0   0      0    2017
# 5777     0.0  2.0   Crystal Palace  ...  1.0   0      0    2017
#
#                          team venue_code opp_code hour day_code  target
# MatchID
# 0                   Liverpool          0       12   12        5       1
# 1                   Liverpool          1        3   16        6       1
# 2                   Liverpool          0       18   16        6       1
# 3                   Liverpool          1       21   15        5       0
# 4                   Liverpool          1        2   15        5       1
# ...                       ...        ...      ...  ...      ...     ...
# 5773     West Bromwich Albion          0       18   16        6       1
# 5774     West Bromwich Albion          1       15   12        5       0
# 5775     West Bromwich Albion          0       19   15        5       1
# 5776     West Bromwich Albion          1       26   15        5       1
# 5777     West Bromwich Albion          0        8   15        6       0
#
# [5778 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < "2023-01-01"]

# %%
test = matches[matches["date"] > "2023-01-01"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6002430133657352

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))
# combined.head()

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           775  240
# 1           418  213

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds) # probablity of model correctly predicting a team's win specifically
# Out:
# 0.47019867549668876

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group.head()
# Out:
#               date   time            comp        round  day venue result   gf  \
# MatchID
# 68      2024-08-18  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0
# 69      2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0
# 70      2024-08-31  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0
# 71      2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0
# 72      2024-09-22  16:30  Premier League  Matchweek 5  Sun  Home      D  2.0
#
#           ga      opponent  ...   fk  pk  pkatt  season             team  \
# MatchID                     ...
# 68       0.0       Chelsea  ...  0.0   0      0    2024  Manchester City
# 69       1.0  Ipswich Town  ...  1.0   1      1    2024  Manchester City
# 70       1.0      West Ham  ...  1.0   0      0    2024  Manchester City
# 71       1.0     Brentford  ...  0.0   0      0    2024  Manchester City
# 72       2.0       Arsenal  ...  1.0   0      0    2024  Manchester City
#
#         venue_code opp_code hour day_code  target
# MatchID
# 68               0        7   16        6       1
# 69               1       12   15        5       1
# 70               0       29   17        5       1
# 71               1        3   15        5       1
# 72               1        0   16        6       0
#
# [5 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = "left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#               date   time            comp         round  day venue result  \
# MatchID
# 5021    2017-09-09  12:30  Premier League   Matchweek 4  Sat  Home      W
# 5022    2017-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W
# 5023    2017-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W
# 5024    2017-09-30  17:30  Premier League   Matchweek 7  Sat  Away      W
# 5025    2017-10-14  15:00  Premier League   Matchweek 8  Sat  Home      W
# ...            ...    ...             ...           ...  ...   ...    ...
# 86      2024-12-29  14:30  Premier League  Matchweek 19  Sun  Away      W
# 87      2025-01-04  15:00  Premier League  Matchweek 20  Sat  Home      W
# 88      2025-01-14  19:30  Premier League  Matchweek 21  Tue  Away      D
# 89      2025-01-19  16:30  Premier League  Matchweek 22  Sun  Away      W
# 90      2025-01-25  17:30  Premier League  Matchweek 23  Sat  Home      W
#
#           gf   ga        opponent  ...  day_code  target  gf_rolling  \
# MatchID                            ...
# 5021     5.0  0.0       Liverpool  ...         5       1    1.666667
# 5022     6.0  0.0         Watford  ...         5       1    2.666667
# 5023     5.0  0.0  Crystal Palace  ...         5       1    4.333333
# 5024     1.0  0.0         Chelsea  ...         5       1    5.333333
# 5025     7.0  2.0      Stoke City  ...         5       1    4.000000
# ...      ...  ...             ...  ...       ...     ...         ...
# 86       2.0  0.0  Leicester City  ...         6       1    1.000000
# 87       4.0  1.0        West Ham  ...         5       1    1.333333
# 88       2.0  2.0       Brentford  ...         1       0    2.333333
# 89       6.0  0.0    Ipswich Town  ...         6       1    2.666667
# 90       3.0  1.0         Chelsea  ...         5       1    4.000000
#
#          ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  \
# MatchID
# 5021       0.666667  17.333333    6.000000    18.566667   1.333333   0.000000
# 5022       0.666667  17.000000    8.000000    16.733333   0.666667   0.000000
# 5023       0.333333  19.666667    9.000000    15.800000   0.333333   0.333333
# 5024       0.000000  21.666667    9.333333    14.900000   0.000000   0.333333
# 5025       0.000000  23.000000    7.666667    16.233333   0.333333   0.333333
# ...             ...        ...         ...          ...        ...        ...
# 86         1.666667  15.000000    4.333333    18.100000   0.333333   0.000000
# 87         1.000000  16.333333    5.000000    17.966667   0.666667   0.000000
# 88         0.666667  15.666667    5.333333    17.366667   0.666667   0.000000
# 89         1.000000  15.000000    6.666667    16.666667   0.333333   0.000000
# 90         1.000000  16.000000    8.000000    15.533333   0.000000   0.000000
#
#          pkatt_rolling
# MatchID
# 5021          0.000000
# 5022          0.000000
# 5023          0.333333
# 5024          0.333333
# 5025          0.333333
# ...                ...
# 86            0.333333
# 87            0.333333
# 88            0.333333
# 89            0.000000
# 90            0.000000
#
# [286 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/j1/qtn9t_2j775dmr1304w_mlmw0000gn/T/ipykernel_39931/4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                       date   time            comp  \
# team                    MatchID
# Arsenal                 5211    2017-09-09  15:00  Premier League
#                         5212    2017-09-17  13:30  Premier League
#                         5213    2017-09-25  20:00  Premier League
#                         5214    2017-10-01  12:00  Premier League
#                         5215    2017-10-14  17:30  Premier League
# ...                                    ...    ...             ...
# Wolverhampton Wanderers 407     2024-12-29  15:00  Premier League
#                         408     2025-01-06  20:00  Premier League
#                         409     2025-01-15  19:30  Premier League
#                         410     2025-01-20  20:00  Premier League
#                         411     2025-01-25  15:00  Premier League
#
#                                         round  day venue result   gf   ga  \
# team                    MatchID
# Arsenal                 5211      Matchweek 4  Sat  Home      W  3.0  0.0
#                         5212      Matchweek 5  Sun  Away      D  0.0  0.0
#                         5213      Matchweek 6  Mon  Home      W  2.0  0.0
#                         5214      Matchweek 7  Sun  Home      W  2.0  0.0
#                         5215      Matchweek 8  Sat  Away      L  1.0  2.0
# ...                                       ...  ...   ...    ...  ...  ...
# Wolverhampton Wanderers 407      Matchweek 19  Sun  Away      D  2.0  2.0
#                         408      Matchweek 20  Mon  Home      L  0.0  3.0
#                         409      Matchweek 21  Wed  Away      L  0.0  3.0
#                         410      Matchweek 22  Mon  Away      L  1.0  3.0
#                         411      Matchweek 23  Sat  Home      L  0.0  1.0
#
#                                         opponent  ...  day_code  target  \
# team                    MatchID                   ...
# Arsenal                 5211         Bournemouth  ...         5       1
#                         5212             Chelsea  ...         6       0
#                         5213           West Brom  ...         0       1
#                         5214            Brighton  ...         6       1
#                         5215             Watford  ...         5       0
# ...                                          ...  ...       ...     ...
# Wolverhampton Wanderers 407            Tottenham  ...         6       0
#                         408      Nott'ham Forest  ...         0       0
#                         409        Newcastle Utd  ...         2       0
#                         410              Chelsea  ...         0       0
#                         411              Arsenal  ...         5       0
#
#                                  gf_rolling  ga_rolling sh_rolling  \
# team                    MatchID
# Arsenal                 5211       1.333333    2.666667  17.666667
#                         5212       1.000000    1.666667  14.333333
#                         5213       1.000000    1.333333  12.000000
#                         5214       1.666667    0.000000  14.333333
#                         5215       1.333333    0.000000  17.000000
# ...                                     ...         ...        ...
# Wolverhampton Wanderers 407        2.000000    0.666667  10.333333
#                         408        2.333333    0.666667   8.666667
#                         409        1.333333    1.666667  10.333333
#                         410        0.666667    2.666667  12.333333
#                         411        0.333333    3.000000  11.666667
#
#                                 sot_rolling dist_rolling fk_rolling  \
# team                    MatchID
# Arsenal                 5211       5.333333    18.133333   0.000000
#                         5212       5.000000    16.766667   0.333333
#                         5213       3.666667    16.566667   0.333333
#                         5214       5.333333    17.400000   1.333333
#                         5215       5.000000    18.333333   1.666667
# ...                                     ...          ...        ...
# Wolverhampton Wanderers 407        4.666667    19.033333   0.666667
#                         408        3.666667    19.566667   1.000000
#                         409        4.000000    19.800000   0.666667
#                         410        5.000000    17.566667   0.333333
#                         411        5.333333    16.466667   0.000000
#
#                                 pk_rolling  pkatt_rolling
# team                    MatchID
# Arsenal                 5211      0.000000       0.000000
#                         5212      0.000000       0.000000
#                         5213      0.000000       0.000000
#                         5214      0.333333       0.333333
#                         5215      0.333333       0.333333
# ...                                    ...            ...
# Wolverhampton Wanderers 407       0.000000       0.000000
#                         408       0.000000       0.000000
#                         409       0.000000       0.000000
#                         410       0.000000       0.000000
#                         411       0.000000       0.000000
#
# [5676 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#               date   time            comp         round  day venue result  \
# MatchID
# 5211    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W
# 5212    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D
# 5213    2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W
# 5214    2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W
# 5215    2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L
# ...            ...    ...             ...           ...  ...   ...    ...
# 407     2024-12-29  15:00  Premier League  Matchweek 19  Sun  Away      D
# 408     2025-01-06  20:00  Premier League  Matchweek 20  Mon  Home      L
# 409     2025-01-15  19:30  Premier League  Matchweek 21  Wed  Away      L
# 410     2025-01-20  20:00  Premier League  Matchweek 22  Mon  Away      L
# 411     2025-01-25  15:00  Premier League  Matchweek 23  Sat  Home      L
#
#           gf   ga         opponent  ...  day_code  target  gf_rolling  \
# MatchID                             ...
# 5211     3.0  0.0      Bournemouth  ...         5       1    1.333333
# 5212     0.0  0.0          Chelsea  ...         6       0    1.000000
# 5213     2.0  0.0        West Brom  ...         0       1    1.000000
# 5214     2.0  0.0         Brighton  ...         6       1    1.666667
# 5215     1.0  2.0          Watford  ...         5       0    1.333333
# ...      ...  ...              ...  ...       ...     ...         ...
# 407      2.0  2.0        Tottenham  ...         6       0    2.000000
# 408      0.0  3.0  Nott'ham Forest  ...         0       0    2.333333
# 409      0.0  3.0    Newcastle Utd  ...         2       0    1.333333
# 410      1.0  3.0          Chelsea  ...         0       0    0.666667
# 411      0.0  1.0          Arsenal  ...         5       0    0.333333
#
#          ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  \
# MatchID
# 5211       2.666667  17.666667    5.333333    18.133333   0.000000   0.000000
# 5212       1.666667  14.333333    5.000000    16.766667   0.333333   0.000000
# 5213       1.333333  12.000000    3.666667    16.566667   0.333333   0.000000
# 5214       0.000000  14.333333    5.333333    17.400000   1.333333   0.333333
# 5215       0.000000  17.000000    5.000000    18.333333   1.666667   0.333333
# ...             ...        ...         ...          ...        ...        ...
# 407        0.666667  10.333333    4.666667    19.033333   0.666667   0.000000
# 408        0.666667   8.666667    3.666667    19.566667   1.000000   0.000000
# 409        1.666667  10.333333    4.000000    19.800000   0.666667   0.000000
# 410        2.666667  12.333333    5.000000    17.566667   0.333333   0.000000
# 411        3.000000  11.666667    5.333333    16.466667   0.000000   0.000000
#
#          pkatt_rolling
# MatchID
# 5211          0.000000
# 5212          0.000000
# 5213          0.000000
# 5214          0.333333
# 5215          0.333333
# ...                ...
# 407           0.000000
# 408           0.000000
# 409           0.000000
# 410           0.000000
# 411           0.000000
#
# [5676 rows x 41 columns]

# %%
matches_rolling.index = range(0, matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 1    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# 2    2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W  2.0
# 3    2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W  2.0
# 4    2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5671 2024-12-29  15:00  Premier League  Matchweek 19  Sun  Away      D  2.0
# 5672 2025-01-06  20:00  Premier League  Matchweek 20  Mon  Home      L  0.0
# 5673 2025-01-15  19:30  Premier League  Matchweek 21  Wed  Away      L  0.0
# 5674 2025-01-20  20:00  Premier League  Matchweek 22  Mon  Away      L  1.0
# 5675 2025-01-25  15:00  Premier League  Matchweek 23  Sat  Home      L  0.0
#
#        ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     0.0      Bournemouth  ...         5       1    1.333333    2.666667
# 1     0.0          Chelsea  ...         6       0    1.000000    1.666667
# 2     0.0        West Brom  ...         0       1    1.000000    1.333333
# 3     0.0         Brighton  ...         6       1    1.666667    0.000000
# 4     2.0          Watford  ...         5       0    1.333333    0.000000
# ...   ...              ...  ...       ...     ...         ...         ...
# 5671  2.0        Tottenham  ...         6       0    2.000000    0.666667
# 5672  3.0  Nott'ham Forest  ...         0       0    2.333333    0.666667
# 5673  3.0    Newcastle Utd  ...         2       0    1.333333    1.666667
# 5674  3.0          Chelsea  ...         0       0    0.666667    2.666667
# 5675  1.0          Arsenal  ...         5       0    0.333333    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     17.666667    5.333333    18.133333   0.000000   0.000000       0.000000
# 1     14.333333    5.000000    16.766667   0.333333   0.000000       0.000000
# 2     12.000000    3.666667    16.566667   0.333333   0.000000       0.000000
# 3     14.333333    5.333333    17.400000   1.333333   0.333333       0.333333
# 4     17.000000    5.000000    18.333333   1.666667   0.333333       0.333333
# ...         ...         ...          ...        ...        ...            ...
# 5671  10.333333    4.666667    19.033333   0.666667   0.000000       0.000000
# 5672   8.666667    3.666667    19.566667   1.000000   0.000000       0.000000
# 5673  10.333333    4.000000    19.800000   0.666667   0.000000       0.000000
# 5674  12.333333    5.000000    17.566667   0.333333   0.000000       0.000000
# 5675  11.666667    5.333333    16.466667   0.000000   0.000000       0.000000
#
# [5676 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < "2023-01-01"]
    test = data[data["date"] > "2023-01-01"]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 1    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# 2    2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W  2.0
# 3    2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W  2.0
# 4    2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5671 2024-12-29  15:00  Premier League  Matchweek 19  Sun  Away      D  2.0
# 5672 2025-01-06  20:00  Premier League  Matchweek 20  Mon  Home      L  0.0
# 5673 2025-01-15  19:30  Premier League  Matchweek 21  Wed  Away      L  0.0
# 5674 2025-01-20  20:00  Premier League  Matchweek 22  Mon  Away      L  1.0
# 5675 2025-01-25  15:00  Premier League  Matchweek 23  Sat  Home      L  0.0
#
#        ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     0.0      Bournemouth  ...         5       1    1.333333    2.666667
# 1     0.0          Chelsea  ...         6       0    1.000000    1.666667
# 2     0.0        West Brom  ...         0       1    1.000000    1.333333
# 3     0.0         Brighton  ...         6       1    1.666667    0.000000
# 4     2.0          Watford  ...         5       0    1.333333    0.000000
# ...   ...              ...  ...       ...     ...         ...         ...
# 5671  2.0        Tottenham  ...         6       0    2.000000    0.666667
# 5672  3.0  Nott'ham Forest  ...         0       0    2.333333    0.666667
# 5673  3.0    Newcastle Utd  ...         2       0    1.333333    1.666667
# 5674  3.0          Chelsea  ...         0       0    0.666667    2.666667
# 5675  1.0          Arsenal  ...         5       0    0.333333    3.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0     17.666667    5.333333    18.133333   0.000000   0.000000       0.000000
# 1     14.333333    5.000000    16.766667   0.333333   0.000000       0.000000
# 2     12.000000    3.666667    16.566667   0.333333   0.000000       0.000000
# 3     14.333333    5.333333    17.400000   1.333333   0.333333       0.333333
# 4     17.000000    5.000000    18.333333   1.666667   0.333333       0.333333
# ...         ...         ...          ...        ...        ...            ...
# 5671  10.333333    4.666667    19.033333   0.666667   0.000000       0.000000
# 5672   8.666667    3.666667    19.566667   1.000000   0.000000       0.000000
# 5673  10.333333    4.000000    19.800000   0.666667   0.000000       0.000000
# 5674  12.333333    5.000000    17.566667   0.333333   0.000000       0.000000
# 5675  11.666667    5.333333    16.466667   0.000000   0.000000       0.000000
#
# [5676 rows x 41 columns]

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print(f"Precision of the model is: {precision}")
# Out:
# Precision of the model is: 0.66876498263

# %%
combined
# Out:
#       actual  prediction
# 203        0           1
# 204        1           1
# 205        1           0
# 206        0           1
# 207        0           1
# ...      ...         ...
# 5671       0           0
# 5672       0           0
# 5673       0           0
# 5674       0           0
# 5675       0           0
#
# [1640 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 203        0           1 2023-01-03                  Arsenal    Newcastle Utd
# 204        1           1 2023-01-15                  Arsenal        Tottenham
# 205        1           0 2023-01-22                  Arsenal   Manchester Utd
# 206        0           1 2023-02-04                  Arsenal          Everton
# 207        0           1 2023-02-11                  Arsenal        Brentford
# ...      ...         ...        ...                      ...              ...
# 5671       0           0 2024-12-29  Wolverhampton Wanderers        Tottenham
# 5672       0           0 2025-01-06  Wolverhampton Wanderers  Nott'ham Forest
# 5673       0           0 2025-01-15  Wolverhampton Wanderers    Newcastle Utd
# 5674       0           0 2025-01-20  Wolverhampton Wanderers          Chelsea
# 5675       0           0 2025-01-25  Wolverhampton Wanderers          Arsenal
#
#      result
# 203       D
# 204       W
# 205       W
# 206       L
# 207       D
# ...     ...
# 5671      D
# 5672      L
# 5673      L
# 5674      L
# 5675      L
#
# [1640 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton",
    "Manchester United" : "Manchester Utd",
    "Newcastle United" : "Newcastle Utd",
    "Tottenham Hotspur" : "Tottenham",
    "West Ham United" : "West Ham",
    "Wolverhampton Wanderers" : "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined.head()
# Out:
#      actual  prediction       date     team        opponent result new_team
# 203       0           1 2023-01-03  Arsenal   Newcastle Utd      D  Arsenal
# 204       1           1 2023-01-15  Arsenal       Tottenham      W  Arsenal
# 205       1           0 2023-01-22  Arsenal  Manchester Utd      W  Arsenal
# 206       0           1 2023-02-04  Arsenal         Everton      L  Arsenal
# 207       0           1 2023-02-11  Arsenal       Brentford      D  Arsenal

# %%
merged = combined.merge(combined, left_on = ["date", "new_team"], right_on = ["date", "opponent"])

# %%
merged.head()
# Out:
#    actual_x  prediction_x       date   team_x      opponent_x result_x  \
# 0         0             1 2023-01-03  Arsenal   Newcastle Utd        D
# 1         1             1 2023-01-15  Arsenal       Tottenham        W
# 2         1             0 2023-01-22  Arsenal  Manchester Utd        W
# 3         0             1 2023-02-04  Arsenal         Everton        L
# 4         0             1 2023-02-11  Arsenal       Brentford        D
#
#   new_team_x  actual_y  prediction_y             team_y opponent_y result_y  \
# 0    Arsenal         0             0   Newcastle United    Arsenal        D
# 1    Arsenal         0             0  Tottenham Hotspur    Arsenal        L
# 2    Arsenal         0             1  Manchester United    Arsenal        L
# 3    Arsenal         1             0            Everton    Arsenal        W
# 4    Arsenal         0             0          Brentford    Arsenal        D
#
#        new_team_y
# 0   Newcastle Utd
# 1       Tottenham
# 2  Manchester Utd
# 3         Everton
# 4       Brentford

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    230
# 0    153
# Name: count, dtype: int64
